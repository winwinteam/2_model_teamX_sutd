# %% [markdown]
# <a href="https://colab.research.google.com/github/winwinteam/2_model_teamX_sutd/blob/main/2_model_teamX_sutd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project requirement
# ![ScreenHunter_01 May. 12 09.27.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # basic usage

# %%
import os
import pandas as pd

# %% [markdown]
# # Utilty functions
